# %%
import pandas as pd
from pathlib import Path

births_total = pd.read_parquet(Path("..") / "data" / "clean" / "births_total.parquet")
population_total = pd.read_parquet(Path("..") / "data" / "clean" / "population_total.parquet")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       2 from pathlib import Path
#       4 births_total = pd.read_parquet(Path("..") / "data" / "clean" / "births_total.parquet")
# ----> 5 population_total = pd.read_parquet(Path("..") / "data" / "clean" / "population_total.parquet")
#
# File c:\PythonProjects\demography-forecast-mvp\venv\Lib\site-packages\pandas\io\parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
# ...

# %%
plt.figure(figsize=(9, 4))
plt.plot(births_total["Year"], births_total["Births_total_year"], label="Факт")
plt.axvline(2021.5, linestyle="--", color="gray", label="граница train / test")
plt.title("Число рождений по годам")
plt.xlabel("Год")
plt.ylabel("Рождений, тыс. чел.")
plt.legend()
plt.tight_layout()
plt.show()

# %%
births_total.describe()
# Out:
#               Year  Births_total_year
# count    34.000000          34.000000
# mean   2006.500000       18104.235294
# std       9.958246        3191.360858
# min    1990.000000       12131.000000
# 25%    1998.250000       15815.000000
# 50%    2006.500000       17546.000000
# 75%    2014.750000       21013.750000
# max    2023.000000       24276.000000
